# %% [markdown]
# # <center>Tarea 1</center>
#
#
#
# Instrucciones:
# 1. Ponle de nombre a tu tarea `tarea_1.ipynb` un Jupyter Notebook (5 points)
# 2. Escribe tu nombre comleto y tus iniciales en tu notebook después de la siguiente nota:
# *Este trabajo es mio y sigue la integridad académica del Tec. de Monterrey*
# 3. Agrega los nombres de todos los compañeros con los que trabajaste. Recuerda que puedes discutir con tus compañeros pero cada quien tiene que entregar su tarea.
# 4. **ADVERTENCIA!** solo puedes utilizar las librerias que explicitamente se mencionen. El uso de cualquier otra libreria para resolver algún ejercicio será tomado como plagio :(
# 5. Librerias: `pandas` y `numpy`
# 6. Descarga to .ipynb y subelo a canvas!
#
#
#
# Introducción:
#
# [Chipotle Mexical Grill](https://www.chipotle.com) es una franquicia de restaurantes de comida rápida con sede en Estados Unidos. La especialidad de esta franquicia es comida Tex-Mex, es decir, gastronomía de la gente mexicano-estado-unidense que vive en Texas. Uno de los produtos estrella es el Burrito, el cual puede incluir una variedad de ingredientes.
#
# En 2015, el New York Times publicó un artículo denominado "At Chipotle, How Many Calories Do People Really Eat?" ([enlace](https://www.nytimes.com/interactive/2015/02/17/upshot/what-do-people-actually-order-at-chipotle.html)), en donde se realiza un análisis sobre cuantas calorias, miligramos de sodio y gramos de grasa saturada están incluidos en las ordenes de dos restaurantes de Chipotle. El análisis presentando en el citado artículo tiene por base la información de cerca de 3000 comidas de alrededor de 1800 órdenes de [Grubhub](https://www.grubhub.com) de Julio a Diciembre de 2012 procedentes de dos restaurants de Chipotle.
#
#
#
# ### Importación del Conjunto de Datos y Características Básicas
#
# 1. Importar el conjunto de datos *chipotle.tsv* que se encuentra en la carpeta *data*. El conjunto de datos original se encuentra ubicado en el siguiente enlace: https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv.
#     1. Asigna la base de datos a un data frame que se llame `Chipotle`
#     2. ¿Cuántas observaciones tiene la base? ¿Qué representa cada renglón?
#     3. ¿Cuántas columnas tiene la base? ¿Qué representan las columnas?
#     4. ¿Cómo esta indexada la base?
#     5. ¿Qué tipo de variables hay?
#
# ### Exploración de la base (básicos de pandas)
# 1. ¿Cuál es el número total de elementos ordenados?
# 2. ¿Cuál es el producto (*item*) que más se ordena y cuántas veces fue ordenado?
# 3. Transforma el precio a `float`, asegurate que el tipo de la variable cambio
# 4. Obten la cantidad total de ingresos (*revenue*).
# 5. Obtener el número total de órdenes.
# 6. Obtener el ingreso promedio por orden.
# 7. ¿Cuántos elementos diferentes *items* hay?
#
#
# ### Filter y Sort
# 1. ¿Cuántos productos cuestan más de 10 dolares?
# 2. ¿Cuál es el precio de cada una de los elementos? Imprime un dataframe solo con dos columnas `item_name` e `item_price`
# 3. Ordena la base de la Z a la A usando el nombre de los items
# 4. ¿Cuántas unidades del item más caro se ordenaron?
# 5. ¿Cuántas veces ordenaron el `Veggie Salad Bowl`?
# 6. ¿Cuántas veces alguién ordeno más de una `Canned Soda`?
