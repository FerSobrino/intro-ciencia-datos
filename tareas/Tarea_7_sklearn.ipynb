# %% [markdown]
# # <center>Tarea 7</center>
#
#
#
# Instrucciones:
# 1. Nombra tu archivo como tarea_7.ipynb en un Jupyter Notebook. (5 puntos)
# 2. Escribe tu nombre completo y tus iniciales en el notebook después de la siguiente declaración:
# *Este trabajo es mío y sigue la integridad académica del Tec. de Monterrey.*
# 3. Incluye los nombres de todos los compañeros con los que discutiste la tarea. Recuerda que puedes discutir los problemas con tus compañeros, pero cada uno debe entregar su propia versión de la tarea.
# 4. **ADVERTENCIA!** Solo está permitido utilizar las librerías que se mencionan explícitamente. El uso de cualquier otra librería para resolver algún ejercicio se considerará como plagio. :(
# 5. Librerias: `pandas`, `numpy`, `sklearn`, `statsmodels`
# 6. Descarga to .ipynb y subelo a canvas!
#
# ### Regresión Logistica
#
# Usa la base de datos `Deafault.xlsx` para el siguiente ejercicio.
#
# 1. ¿Cuántas observaciones contiene la base de datos y qué representa cada una? ¿Cuántas columnas hay?
# 1. Analiza la relación entre `balance`, `income` y `default`. ¿Notas algún patrón entre estas tres variables?
# 1. Examina la relación entre `balance` y `default`, así como entre `income` y `default`. ¿Se observa más claramente la relación al analizar las variables de esta manera?
# 1. Con base en toda la muestra, predice `default` utilizando únicamente `balance`.
#    1. ¿Cuáles son los coeficientes del modelo y cómo los interpretarías?
#    1. Empleando el modelo Logit de `statsmodels`, obtén los coeficientes y errores estándar para `balance`. ¿Qué puedes interpretar de estos resultados?
# 1. Entrena una regresión logística para predecir `default` nuevamente usando solo `balance`. El conjunto de prueba debe ser el 20% del total de los datos. Utiliza `random_state = 200`.
#    1. Presenta la matriz de confusión de tu conjunto de entrenamiento.
#    1. ¿Qué otra métrica sería adecuada en este caso? Justifica su uso y calcula dicha métrica.
# 1. Predice default utilizando toda la muestra y las variables `balance`, `student` e `income` con `statsmodels`. Responde a lo siguiente:
#    1. ¿Qué coeficientes son positivos y cuáles negativos? ¿Tienen sentido estos coeficientes?
#    1. ¿Cuáles coeficientes son sifgnificativos? ¿Cómo los interpretamos?
# 1. Entrena una regresión logística para predecir `default` usando `balance`, `student` e `income`. El conjunto de prueba debe ser el 20% del total de los datos. Utiliza `random_state = 200`.
#    1. Muestra la matriz de confusión de tu conjunto de entrenamiento.
#    1. Calcula la misma métrica que usaste para el modelo con una sola variable.
#    1. ¿Cuál modelo tiene un mejor desempeño y por qué?
#
#
# ### KNN
#
# Para esta sección, utilizaremos la base de datos `Caravan.csv`, que contiene información sobre clientes de una compañía de seguros e incluye 86 variables con datos del seguro y del cliente. Puedes consultar el significado de cada variable en el siguiente [link](https://www.kaggle.com/datasets/uciml/caravan-insurance-challenge/data). Nuestro objetivo es predecir quién comprará un seguro para su caravana.
#
# 1. Explora la relación entre todas las variables y `purchase`. ¿Identificas alguna variable que esté fuertemente relacionada con la compra del seguro?
# 1. Explora gráficamente la relación entre estas variables.
# 1. Identifica el tipo de variables con las que estás trabajando. ¿Es necesario estandarizarlas si queremos usar KNN?
#     1. Si es necesario estandarizarlas, que tipo de estandirzación utilizarías y ¿por qué?
#     1. Ten mucho cuidado en como escalas tus datos. ¿Es correcto escalar toda la muestra junta? Si/No y por qué
# 1. Entrena un modelo KNN utilizando las primeras 1000 observaciones para el conjunto de prueba y el resto para el conjunto de entrenamiento. Ojo si decidiste escalar tus datos, estos son los que tienes que usar!
#     1.  Comienza entrenando con un solo vecino. Presenta la matriz de confusión y calcula la precisión (accuracy). ¿Qué tan bien funciona el modelo?
#     1. ¿Tiene sentido esta métrica? Se te ocurre una mejor métrica. Calcula y argumenta por qué es mejor que usar accuracy en este caso.
#     1. Determina el valor óptimo de `k` utilizando la F1 como criterio.
#     1. Muestra gráficamente la relación entre el número de vecinos y la F1.
#
#
#
# ### Árboles
#
# Para esta sección, usaremos la base de datos `Hitters.csv`, que contiene estadísticas de jugadores de béisbol de 1986. Queremos predecir el salario de los jugadores utilizando diferentes estadísticas de juego.
#
# 1. Examina la base de datos y determina cuántos valores faltantes hay. Considerando nuestro objetivo, ¿qué harías con los valores faltantes?
# 1. Implementa la estrategia que argumentaste anteriormente para manejar los valores faltantes.
# 1. Analiza la distribución del salario de los jugadores, especialmente la relación entre los años que llevan en las ligas mayores (`Years`) y el número de `Hits`.
# 1. Divide los datos en conjuntos de entrenamiento y prueba, utilizando el 30% para la prueba y `random_state = 0`. Acá tira cualquier feature que no necesitemos y cambia cualquier variable categorica a númerica, el random forest no acepta variables categorícas así que conviertelas antes de continuar.
# 1. Entrena un árbol de decisión utilizando solo `Years` y `Hits` como características y establece `max_leaf_nodes=3`.
#    1. ¿Qué implica establecer `max_leaf_nodes=3`? ¿Tiene sentido en este caso?
# 1. Grafica el árbol e interpreta los resultados.
# 1. ¿Qué métrica utilizarías para evaluar el desempeño de tu árbol? Calcula esta métrica para tu conjunto de prueba.
# 1. Compara gráficamente el salario real de los jugadores con el salario predicho por tu árbol.
#    1. ¿Qué está pasado acá? ¿Por qué se ve así la gráfica?
# 1. Entrena un bosque aleatorio (random forest) utilizando todas las características disponibles. Usa los mismos conjuntos de entreamiento y aprendizaje que dividiste al principio. OJO: ahora queremos todas las features!
#    1. Utiliza la misma métrica que arriba. ¿Cómo lo hizo tu random forest?
#    1. Gráfica la feature importance de tu RF. ¿Qué variables aparecen en tu gráfica? Crees que esto tiene setido
#    1. Nunca le dimos cuantas features por árbol va a usar el random forest. ¿Cuál es el default en este caso?
# 1. Vuelve a entrena tu random forest pero ahora utiliza 8, 6 y 3 `max_features`. Para cada uno de estos:
#    1. Calcula la métrica que seleccionaste arriba
#    1. Gráfica la feature importance
# 1. ¿Qué puedes concluir de los distintos RF que corriste? ¿Cuál es mejor? ¿Por qué?
