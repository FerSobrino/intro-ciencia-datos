# %% [markdown]
# # <center>Tarea 7 — Mini colaboración con IA</center>
#
# **Instrucciones:**
#
# 1. Nombra tu archivo `tarea_7.ipynb` (5 puntos).
# 2. Escribe tu nombre completo y, después, esta declaración:
#    *Este trabajo es mío y sigue la integridad académica del Tec de
#    Monterrey. La transcripción de IA que entrego corresponde
#    íntegramente a este trabajo.*
# 3. Anota los nombres de los compañeros con quienes discutiste la
#    tarea.
# 4. Uso de IA: permitido. Adjunta la transcripción completa de tus
#    conversaciones (archivo aparte o celda al final). Sin
#    transcripción, la tarea no se califica. Si no usaste IA,
#    decláralo.
# 5. Incluye la sección final de **Verificación**.
# 6. Descarga tu `.ipynb` y súbelo a Canvas junto con la transcripción.
#
# ---
#
# **Puntos por sección**
#
# | Sección | Puntos |
# |---|---|
# | 1. Especificación | 25 |
# | 2. Implementación con el agente | 15 |
# | 3. Auditoría | 30 |
# | 4. Interpretación | 15 |
# | 5. Verificación | 10 |
# | Nombre del archivo, declaración y compañeros | 5 |
# | **Total** | **100** |
#
# ---
#
# ## De qué se trata esta tarea
#
# En las tareas anteriores tú escribías el código. En esta, lo escribe un agente de IA y tú lo
# diriges, lo auditas y lo firmas.
#
# El cambio no es un atajo: es más difícil. Un agente hace **exactamente lo que le pides**. Si no
# sabes pedir una separación train/test antes de escalar, no la vas a obtener; si no sabes que
# `accuracy` es una métrica inútil cuando el 3% de los casos son positivos, vas a recibir un
# modelo con 97% de exactitud que no sirve para nada y no vas a notarlo. El agente pone el código;
# tú pones el entendimiento.
#
# Por eso se califica en este orden: **especificar bien, verificar con escepticismo, interpretar con
# criterio**. Nota lo que *no* se califica: la elegancia del código (lo escribió el agente) ni qué
# tan buenos salieron los números. Un análisis con resultados mediocres, bien especificado, bien
# auditado y bien interpretado saca mejor nota que uno con números espectaculares que no puedes
# explicar.
#
# **Descalificación automática:** entregar sin la transcripción completa de tus conversaciones con
# el agente, o una transcripción que no corresponda a los resultados que reportas.
#
# Cualquiera de tus tareas entregadas puede tocarte en una **defensa
# oral** (10 minutos, sin IA, con tu notebook abierto). Antes de entregar,
# pregúntate: *¿podría explicar y modificar cada celda de esto?* Si una
# celda no la entiendes, pídele al agente que te la explique — para eso sí
# es buenísimo.

# %%
## Escribe aquí tu nombre completo, la declaración requerida y con quién trabajaste.

# %% [markdown]
# ## Elige tu problema
#
# Escoge **una** de las tres opciones. Las tres usan bases clásicas que están en la carpeta `data`
# del repositorio. Trabaja esa opción de principio a fin: la especificación, la implementación, la
# auditoría y la interpretación se refieren toda la tarea al mismo problema.
#
# ---
#
# ### Opción A — Regresión logística: ¿quién va a caer en impago?
#
# **Datos:** `../data/Default.xlsx`. Cada renglón es un tarjetahabiente. La variable a predecir es
# `default` (¿incumplió el pago?), y las covariables disponibles son `balance` (saldo),
# `income` (ingreso) y `student` (si es estudiante).
#
# **Contenido mínimo que tu análisis debe cubrir:**
#
# - Cuántas observaciones y columnas hay, y qué representa cada renglón.
# - La relación entre `balance`, `income` y `default`: exploración gráfica que muestre por qué una
#   de las dos covariables numéricas separa mucho mejor que la otra.
# - Un modelo con `balance` sola y un modelo con `balance`, `student` e `income`. Interpretación de
#   los coeficientes: cuáles son positivos, cuáles negativos, cuáles significativos, y si tienen
#   sentido. (El coeficiente de `student` cambia de signo dependiendo de qué otras variables estén
#   en el modelo — si eso te aparece, explícalo, no lo escondas.)
# - Evaluación de ambos modelos en un conjunto de prueba del 20%, con `random_state = 200`, y una
#   conclusión sobre cuál es mejor y por qué.
#
# ---
#
# ### Opción B — KNN: ¿quién va a comprar el seguro?
#
# **Datos:** `../data/Caravan.csv`. Contiene información de clientes de una compañía de seguros, con
# 86 variables de cliente y de póliza. Puedes consultar el significado de cada variable en este
# [link](https://www.kaggle.com/datasets/uciml/caravan-insurance-challenge/data). El objetivo es
# predecir quién comprará un seguro para su caravana (`Purchase`).
#
# **Contenido mínimo que tu análisis debe cubrir:**
#
# - Exploración de la relación entre las variables y `Purchase`: ¿identificas alguna variable
#   fuertemente relacionada con la compra? Muéstralo gráficamente.
# - Identificación del tipo de variables con las que estás trabajando y la decisión de
#   estandarización (ver los dos *riders* obligatorios más abajo).
# - Un modelo KNN usando las primeras 1000 observaciones como conjunto de prueba y el resto como
#   entrenamiento. Empieza con un solo vecino.
# - Búsqueda del valor óptimo de `k` con el criterio que definas en tu especificación, y una gráfica
#   de la relación entre el número de vecinos y esa métrica.
#
# ---
#
# ### Opción C — Árboles y bosques: ¿cuánto gana un pelotero?
#
# **Datos:** `../data/Hitters.csv`. Estadísticas de jugadores de béisbol de 1986; queremos predecir
# el salario a partir de sus estadísticas de juego.
#
# **Contenido mínimo que tu análisis debe cubrir:**
#
# - Cuántos valores faltantes hay y qué haces con ellos, argumentado a partir del objetivo.
# - La distribución del salario, y su relación con `Years` y `Hits`.
# - División en entrenamiento y prueba con 30% de prueba y `random_state = 0`, tirando las columnas
#   que no sirvan y convirtiendo las categóricas a numéricas.
# - Un árbol de decisión con solo `Years` y `Hits` y `max_leaf_nodes=3`, graficado e interpretado.
#   ¿Qué implica fijar `max_leaf_nodes=3` y tiene sentido aquí? Compara gráficamente el salario real
#   contra el predicho: ¿por qué se ve así esa gráfica?
# - Un random forest con todas las características, sobre los mismos conjuntos, con su gráfica de
#   *feature importance*. ¿Cuál es el `max_features` por defecto en este caso?
# - El random forest reentrenado con `max_features` de 8, 6 y 3, con la métrica y la *feature
#   importance* de cada uno, y una conclusión sobre cuál es mejor y por qué.

# %% [markdown]
# ### Dos preguntas obligatorias, elijas la opción que elijas
#
# Estas dos van en tu especificación (sección 1) y se vuelven a revisar en la auditoría (sección 3).
# Son las preguntas que más seguido contesta mal un agente:
#
# 1. **¿Es necesario estandarizar las variables para el modelo que elegiste?** Contesta con el
#    criterio, no con la costumbre: ¿de qué depende que un modelo necesite escalamiento? Si tu
#    respuesta es que sí, ¿qué tipo de estandarización usarías y por qué esa?
# 2. **¿Es correcto escalar toda la muestra junta?** Sí o no, y por qué. Si tu respuesta es que no,
#    describe el orden exacto de las operaciones que sí es correcto.

# %% [markdown]
# ## 1. Especificación (25 puntos)
#
# **Escribe esta sección completa antes de abrir el chat con el agente.** Después se congela: si más
# adelante te das cuenta de que algo estaba mal, no la borres — agrega abajo "Corrección:" con lo
# que cambiaste y por qué. Una especificación corregida honestamente vale más que una que
# milagrosamente coincide con lo que salió.
#
# La especificación es un contrato. Lo que no esté en ella, el agente no te lo va a dar. Debe
# contener:
#
# 1. **La pregunta.** Una oración, en términos del problema, no del algoritmo. "¿Podemos
#    identificar, antes de que ocurra, a los tarjetahabientes que van a incumplir?" es una pregunta;
#    "correr una regresión logística" no lo es.
#
# 2. **Datos.** Archivo, unidad de observación, número de renglones que esperas, variable a predecir
#    y covariables que vas a permitir. Di explícitamente qué columnas **no** deben entrar al modelo
#    y por qué (identificadores, columnas vacías, columnas que no existirían al momento de predecir).
#
# 3. **Balance de clases y la métrica correcta.** Antes de modelar, cuenta cuántos casos positivos
#    hay como proporción del total. Con ese número en la mano, decide la métrica y **justifícala**.
#    Ojo con esto: en `Default` incumple alrededor del 3% y en `Caravan` compra alrededor del 6%. Un
#    modelo que predice "nadie incumple" para todos acierta el 97% de las veces. Si tu métrica no
#    distingue ese modelo inútil de uno bueno, es la métrica equivocada. Escribe:
#    - la proporción de positivos,
#    - qué accuracy tendría el modelo trivial que siempre predice la clase mayoritaria,
#    - qué métrica vas a usar en su lugar y qué error te importa más evitar (¿un falso positivo o un
#      falso negativo?) *en términos del problema*: ¿qué le cuesta al banco / a la aseguradora cada
#      tipo de error?
#
#    (Si elegiste la Opción C el problema es de regresión y no hay clases; en ese caso justifica la
#    métrica de error que vas a usar y por qué, dada la distribución del salario, y di qué unidades
#    tiene esa métrica.)
#
# 4. **Protocolo de validación.** Cómo se separan los datos (proporción, semilla, si es aleatorio o
#    por bloques), qué preprocesamiento se aplica y **en qué orden respecto a la separación**.
#
# 5. **Modelo(s).** Cuál o cuáles, con qué hiperparámetros fijos y cuáles se van a buscar. Si vas a
#    comparar dos, di qué se mantiene idéntico entre ambos para que la comparación sea justa.
#
# 6. **Las dos preguntas obligatorias** de la celda anterior, contestadas.
#
# 7. **Qué esperas ver.** Una predicción tuya, escrita antes de correr nada: ¿qué variable esperas
#    que salga más importante? ¿Esperas que el modelo complejo le gane al simple? Después vas a
#    contrastar. Equivocarte aquí no baja puntos; no haber escrito nada, sí.

# %% [markdown]
# **Tu especificación aquí** (edita esta celda de markdown, antes de hablar con el agente)
#
# **Opción elegida:**
#
# **1. Pregunta:**
#
# **2. Datos** (archivo, unidad, renglones esperados, variable a predecir, covariables permitidas, columnas excluidas y por qué):
#
# **3. Balance de clases y métrica:**
# - Proporción de positivos:
# - Accuracy del modelo trivial:
# - Métrica elegida y por qué:
# - Error más costoso en términos del problema:
#
# **4. Protocolo de validación** (split, semilla, orden de operaciones):
#
# **5. Modelo(s) e hiperparámetros:**
#
# **6. Las dos preguntas obligatorias:**
# - ¿Es necesario estandarizar?
# - ¿Es correcto escalar toda la muestra junta?
#
# **7. Qué espero ver:**
#
# **Correcciones posteriores** (si las hubo, con fecha y motivo):

# %% [markdown]
# ## 2. Implementación con el agente (15 puntos)
#
# Ahora sí, abre el chat. Usa el agente que quieras (ChatGPT, Claude, Gemini, Copilot, Claude Code,
# el que prefieras) y dirígelo para que implemente tu especificación.
#
# **Cómo se califica esta sección:** por la calidad de la dirección, no por la del código.
# Concretamente:
#
# - **Pega el prompt inicial completo**, tal como lo escribiste. Debe reflejar tu especificación: si
#   tu prompt fue "hazme un KNN con Caravan.csv", perdiste los puntos de esta sección aunque el
#   código funcione.
# - **Referencia a la transcripción.** Di cuántas sesiones usaste, con qué herramienta, y en qué
#   parte del archivo de transcripción está cada una. La transcripción íntegra se entrega aparte.
# - **El código final** va en la celda de abajo y tiene que correr de arriba a abajo en tu notebook,
#   produciendo los resultados que reportas. Si tuviste que arreglar algo a mano para que corriera,
#   dilo aquí (y desarróllalo en la auditoría).
#
# Un consejo que ahorra tiempo: **pídele el plan antes que el código** y compáralo contra tu
# especificación antes de dejarlo escribir nada. Es mucho más barato corregir un plan de cinco
# renglones que auditar cincuenta líneas de código.

# %% [markdown]
# **Herramienta(s) y sesiones:**
#
# **Prompt inicial (copiado tal cual):**
#
# ```
# ...
# ```
#
# **Dónde está cada sesión en mi transcripción:**
#
# **Cosas que tuve que arreglar a mano para que corriera:**

# %%
# Código final del agente, revisado por ti. Debe correr completo y producir los resultados
# que reportas en las secciones 3 y 4.

# %% [markdown]
# ## 3. Auditoría (30 puntos)
#
# La sección más importante de la tarea. Aquí demuestras que leíste el código en lugar de solo
# ejecutarlo.
#
# ### a. Lista de verificación (15 pts)
#
# Contesta cada punto con **evidencia**: el número de línea, el fragmento de código o la salida que
# te permite afirmarlo. "Sí lo revisé" sin evidencia no cuenta.
#
# | # | Pregunta | Qué contestar |
# |---|---|---|
# | 1 | ¿Escaló antes o después del split? | Cita las líneas y su orden. ¿El escalador se ajustó (`fit`) con todos los datos o solo con entrenamiento? |
# | 2 | ¿La métrica coincide con la de tu especificación? | Si el agente reportó accuracy y tú pediste otra cosa, es un hallazgo. |
# | 3 | ¿Evaluó sobre el conjunto de prueba? | Busca sobre qué conjunto se llama `predict` en cada `print` de métricas. Es un error frecuentísimo y silencioso. |
# | 4 | ¿Usó la semilla y la proporción de split que especificaste? | Verifica el valor exacto. |
# | 5 | ¿Entró alguna columna que no debía? | Identificadores, columnas vacías, la propia variable a predecir disfrazada, o columnas que no existirían al momento de predecir. Cuenta cuántas columnas tiene la matriz de covariables y checa que el número te cuadre. |
# | 6 | ¿Cuál es la clase positiva? | ¿`sklearn` está tomando como positiva la que a ti te interesa? Si predices impago, la clase positiva debería ser "sí incumplió". |
# | 7 | ¿Cómo trató los faltantes? | ¿Los imputó, los tiró, o `sklearn` los tiró por él sin avisar? ¿Cuántos renglones sobrevivieron? |
#
# ### b. Hallazgos (15 pts)
#
# **Documenta al menos dos errores o decisiones cuestionables del agente**, cada uno con: qué
# encontró, cómo lo detectaste, por qué está mal, y qué hiciste al respecto.
#
# En nuestra experiencia siempre hay al menos uno. Los más comunes en este tipo de problema:
# escalar toda la muestra junta, reportar accuracy en un problema desbalanceado, evaluar sobre
# entrenamiento, dejar la columna de índice (`Unnamed: 0`) como covariable, elegir `k` con la
# métrica equivocada, o "mejorar" el resultado cambiando la semilla hasta que salga bonito.
#
# Si de verdad no encontraste ninguno, no inventes: explica punto por punto qué revisaste para
# descartarlos. Eso también se califica — pero el estándar de evidencia es más alto.

# %% [markdown]
# **Tu auditoría aquí** (edita esta celda de markdown)
#
# **a. Lista de verificación**
#
# | # | Respuesta | Evidencia (línea / código / salida) |
# |---|---|---|
# | 1 | | |
# | 2 | | |
# | 3 | | |
# | 4 | | |
# | 5 | | |
# | 6 | | |
# | 7 | | |
#
# **b. Hallazgo 1**
# - Qué encontré:
# - Cómo lo detecté:
# - Por qué está mal:
# - Qué hice:
#
# **b. Hallazgo 2**
# - Qué encontré:
# - Cómo lo detecté:
# - Por qué está mal:
# - Qué hice:

# %%
# Código de tu auditoría: los chequeos que corriste para detectar o descartar los hallazgos.
# Por ejemplo: contar columnas de X, verificar la clase positiva, recalcular la métrica sobre test.

# %% [markdown]
# ## 4. Interpretación (15 puntos)
#
# Ya tienes resultados auditados. ¿Y ahora qué? Escribe entre media y una página que conteste:
#
# 1. **La respuesta a tu pregunta.** En términos del problema, no del algoritmo. No "el modelo
#    obtuvo F1 de 0.31", sino qué significa ese 0.31 para quien tiene que tomar la decisión: si la
#    aseguradora usa tu modelo para llamar a 1000 clientes, ¿a cuántos compradores reales alcanza y
#    cuántas llamadas desperdicia? Traduce la métrica a la unidad que le importa a la organización.
#
# 2. **Contraste con tu predicción.** Compara con lo que escribiste en el punto 7 de la
#    especificación. ¿Le atinaste? Si no, ¿qué explica la diferencia? Esta es la pregunta que más
#    aprendizaje produce de toda la tarea.
#
# 3. **Interpretación sustantiva.** ¿Qué variables resultaron importantes y tiene sentido que lo
#    sean? Cuidado con el salto causal: que `balance` prediga el impago no significa que bajarle el
#    saldo a alguien lo vuelva buen pagador.
#
# 4. **Limitaciones.** Al menos tres, concretas y de este análisis, no genéricas. Por ejemplo:
#    los datos son de 1986 y la estructura salarial del béisbol cambió por completo; el conjunto de
#    prueba tiene tan pocos casos positivos que la métrica es muy inestable; la muestra no
#    representa a la población a la que se aplicaría el modelo.
#
# 5. **Recomendación.** ¿Recomendarías usar este modelo para tomar decisiones reales? Sí, no, o bajo
#    qué condiciones. Una respuesta honesta de "no todavía, porque..." vale más que un sí
#    entusiasta.

# %% [markdown]
# **Tu interpretación aquí** (edita esta celda de markdown)
#
# **1. La respuesta, en términos del problema:**
#
# **2. Contraste con mi predicción:**
#
# **3. Interpretación sustantiva:**
#
# **4. Limitaciones:**
#
# **5. Recomendación:**

# %% [markdown]
# ## 5. Verificación (10 puntos)
#
# Cierra con evidencia reproducible. Los tres chequeos se corren en la celda de abajo, con código
# tuyo — no del agente — y cada uno se responde con números.
#
# 1. **La métrica por dos caminos (4 pts).** Toma la métrica principal de tu especificación y
#    calcúlala otra vez desde la matriz de confusión, a mano, con los cuatro conteos. Compárala con
#    la que devuelve `sklearn`. Deben coincidir hasta al menos tres decimales. Si no coinciden,
#    encuentra por qué antes de entregar: casi siempre es la clase positiva, el promediado (`macro`
#    vs. `binary`) o el conjunto sobre el que se evaluó. (Opción C: recalcula tu métrica de error a
#    mano a partir de `y_test` y `y_pred`.)
#
# 2. **El modelo trivial como piso (3 pts).** Calcula la métrica de un modelo que siempre predice la
#    clase mayoritaria (Opción C: uno que siempre predice el salario promedio de entrenamiento).
#    Reporta ambos números juntos. **Si tu modelo no le gana al trivial, dilo** — no es una tarea
#    reprobada, es un hallazgo, y esconderlo sí baja puntos.
#
# 3. **Conteos que cuadran (3 pts).** Verifica que `len(train) + len(test)` sea igual al número de
#    renglones que usaste, que ese número corresponda a lo que dijiste en tu especificación, y
#    que la matriz de covariables tenga exactamente las columnas que autorizaste (imprime
#    `X.shape` y la lista de nombres). Reporta si el número de renglones cambió en algún punto del
#    pipeline y por qué.
#
# Cierra con una línea sobre el uso de IA: los errores que documentaste en la auditoría, o qué
# revisaste para descartarlos.

# %%
# Chequeo 1: métrica recalculada a mano desde la matriz de confusión.
# Chequeo 2: métrica del modelo trivial.
# Chequeo 3: conteos de renglones y columnas.

# %% [markdown]
# **Conclusiones de tu verificación aquí** (edita esta celda de markdown)
#
# 1. Métrica a mano: ___ vs. `sklearn`: ___ . ¿Coinciden?
# 2. Mi modelo: ___ vs. modelo trivial: ___ . ¿Le gana?
# 3. Renglones train + test = ___ = total ___ . Columnas de X: ___ (¿son las autorizadas?)
# 4. Uso de IA — errores encontrados o qué revisé para descartarlos:
