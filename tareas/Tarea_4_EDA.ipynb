# %% [markdown]
# # <center>Tarea 4</center>
#
#
#
# Instrucciones:
# 1. Ponle de nombre a tu tarea `tarea_4.ipynb` un Jupyter Notebook (5 points)
# 2. Escribe tu nombre completo y tus iniciales en tu notebook después de la siguiente nota:
# *Este trabajo es mio y sigue la integridad académica del Tec. de Monterrey*
# 3. Agrega los nombres de todos los compañeros con los que trabajaste. Recuerda que puedes discutir con tus compañeros pero cada quien tiene que entregar su tarea.
# 4. **ADVERTENCIA!** solo puedes utilizar las librerias que explicitamente se mencionen. El uso de cualquier otra libreria para resolver algún ejercicio será tomado como plagio :(
# 5. Librerias: `pandas`, `numpy`, `matplotlib`, `seaborn` y `scipy.stats`.
# 6. Para está tarea usaras distintos datasets, todos estan en Gitlab en la carpeta `data/OrigenDestino`
# 7. Descarga tu .ipybn y subelo a canvas!
#
# ## Base de datos de viajes (25 pts)
# 1. ¿Cuántas variables y cuántos renglones tiene la base de viajes? ¿Qué representa cada renglón? ¿Qué variable es la llave primaria de esta base?
# 1. Define los viajes validos de la siguiente manera: viajes para los que tenemos estado de origen y de destino. ¿Cuántos viajes validos hay? ¿Desde cuántos estados distintos empiezan los viajes?
# 1. ¿Cuáles son las 5 razones menos comunes para viajar? Ignora los missing values
# 1. ¿Qué porcentaje de los viajes ocurren entre semana y qué porcentaje los fines de semana?
# 1. ¿Cuál es la diferencia entre las razones de los viajes entre semana y en fin de semana? Utiliza una gráfica para contestar.
# 1. ¿Dónde se originan la mayoría de los viajes? ¿Dónde terminan la mayoría de los viajes?  ¿Son simétricas estas dos distribuciones? (es decir por cada viaje de ida hay uno de vuelta al mismo lugar)
# 1. Explora la distribución de sexo y edad. Observas algo extraño en la distribución de edad ¿por qué crees que ocurre esto?
# 1. ¿Cuánto tardan los viajes en promedio? (Guarda esta variable para después). Haz una gráfica de la distribución del tiempo de viaje. ¿Puedes restringir la muestra para que la gráfica sea más informativa? ¿Existe algún patrón extraño en los tiempos de viajes? ¿Por qué pasa esto?
#
#
#
# ##  Base de datos de transportes (20 pts)
# 1. ¿Cuántas variables y cuántos renglones tiene la base de transporte? ¿Qué representa cada renglón? ¿Qué variable es la llave primaria de esta base?
# 1. ¿Cuántos medios de transporte hay en esta base?
# 1. ¿Cuánto tardan en promedio los viajes por medio de transporte? Muestra esto en un histograma. ¿Cuál es la diferencia entre este histograma y el del tiempo por viaje de arriba?
# 1. ¿En promedio cuantos medios de transporte se utilizan por viaje? ¿En promedio cuánto gastan los usuarios por medio de transporte? ¿En promedio cuanto gastan por viaje?
#
#
# ## Juntando las dos base (10 pts)
# 1. Identifica que variable o variables nos permite juntar estas dos bases de datos. Junta las dos bases. ¿Qué tipo de merge hiciste acá y por qué?
# 1. ¿Cuántas observaciones y cuantas variables tiene esta nueva base? ¿Qué representa cada observación? ¿Qué información extra tenemos que antes no teníamos?
# 1. Define los viajes validos como arriba (aquellos para los que tenemos estado de origen y de destino). ¿Cuántas trayectos (tramo de viaje realizado solo en un medio de transporte) hay?
#
#
# ## Ejercicio práctico: Investigemos los viajes en bicicleta y en transporte público (40 pts)
# 1. Restringe la base a trayectos dentro de la Ciudad de México (código de estado 09) y a trayectos de los que conocemos el municipio y distrito.
#     a. ¿Cuántos trayectos hay dentro de la Ciudad de México? ¿Cuántos viajes?
#     a. ¿Cuántos trayectos pasan dentro del mismo municipio? ¿Qué proporción de los trayectos dentro de la Ciudad representan?
#     a. ¿Cuántos trayectos pasan dentro del mismo distrito? ¿Qué proporción de todos los trayectos dentro de la Ciudad representan? ¿Qué proporción de los trayectos dentro de los municipios representan?
# 1. Re clasifica los medios de transporte de manera que sólo tengas las siguientes categorías en una nueva variable. Auto(auto/taxi/uber), Bici, Caminar, Transporte publico, otros (otro, transporte escolar, transporte de personal, motos). ¿Cuántos trayectos hay por cada categoría? ¿Cuál es el promedio de gasto y de tiempo por categoría? A partir de ahora puedes usar esta re clasificación salvo que se indique lo contrario.
# 1. ¿Son más cortos/largos los trayectos en bici (incluyendo los bici taxis) comparados con otros medios de transporte? Puedes usar las categoría agrupadas. ¿Cómo se ve la distribución de tiempo por medio de transporte? Recuerda restringir tu gráfica para que sea más fácil de leer.
# 1. ¿Qué medio de transporte es el más común para trayectos dentro del mismo distrito? ¿Para trayectos dentro del mismo municipio? ¿Qué pasa con los viajes en bici?
# 1. Muestra la distribución de cuando empiezan los viajes (puedes usar `dep_hour` ojo viajes no trayectos). ¿Difiere esta distribución por medio de transporte? ¿Cómo se ve la distribución para viajes que solo pasan en bici? Puedes ignorar los viajes que ocupan más de un medio de transporte para esta pregunta.
# 1. Explora la relación entre sexo, edad y la decisión de caminar o salir en bici. Encuentras alguna diferencia entre quienes usan bicicleta y quienes no?
# 1. Escribe una conclusión breve de la diferencia entre los viajes en bici y los demás viajes dentro de la ciudad.
# 1. Existen varias razones por las que la gente puede decidir no salir en bicicleta. Puedes pensar en al menos dos? ¿Qué otros datos necesitarías para comprobar si tus teorías son ciertas? (no necesitas conseguir mas datos solo escribir que necesitarías y por que esto probaría que la gente no usa bici por x o y razón)
