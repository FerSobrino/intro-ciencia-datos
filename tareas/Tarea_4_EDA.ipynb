# %% [markdown]
# # <center>Tarea 4</center>
#
# **Instrucciones:**
#
# 1. Nombra tu archivo `tarea_4.ipynb` (5 puntos).
# 2. Escribe tu nombre completo y, después, esta declaración:
#    *Este trabajo es mío y sigue la integridad académica del Tec de
#    Monterrey. La transcripción de IA que entrego corresponde
#    íntegramente a este trabajo.*
# 3. Anota los nombres de los compañeros con quienes discutiste la
#    tarea.
# 4. Uso de IA: permitido. Adjunta la transcripción completa de tus
#    conversaciones (archivo aparte o celda al final). Sin
#    transcripción, la tarea no se califica. Si no usaste IA,
#    decláralo.
# 5. Incluye la sección final de **Verificación**.
# 6. Descarga tu `.ipynb` y súbelo a Canvas junto con la transcripción.
#
# **Datos:** Encuesta Origen-Destino de la Zona Metropolitana del Valle de México.
# Las dos bases están en `../data/OrigenDestino/`: `Viajes.csv.gz` y `Transporte.csv.gz`.
#
# **Puntos:** nombre y declaración 5 · Base de viajes 16 · Base de transportes 11 ·
# Juntando las dos bases 8 · Ejercicio práctico 20 · Resumen ejecutivo bajo
# sospecha 25 · Verificación 15 = **100**

# %% [markdown]
# ## Base de datos de viajes (16 puntos)
# 1. ¿Cuántas variables y cuántos renglones tiene la base de viajes? ¿Qué representa cada renglón? ¿Qué variable es la llave primaria de esta base?
# 1. Define los viajes válidos de la siguiente manera: viajes para los que tenemos estado de origen y de destino. ¿Cuántos viajes válidos hay? ¿Desde cuántos estados distintos empiezan los viajes?
# 1. ¿Cuáles son las 5 razones menos comunes para viajar? Ignora los missing values
# 1. ¿Qué porcentaje de los viajes ocurren entre semana y qué porcentaje los fines de semana?
# 1. ¿Cuál es la diferencia entre las razones de los viajes entre semana y en fin de semana? Utiliza una gráfica para contestar.
# 1. ¿Dónde se originan la mayoría de los viajes? ¿Dónde terminan la mayoría de los viajes? ¿Son simétricas estas dos distribuciones? (es decir, ¿por cada viaje de ida hay uno de vuelta al mismo lugar?)
# 1. Explora la distribución de sexo y edad. ¿Observas algo extraño en la distribución de edad? ¿Por qué crees que ocurre esto?
# 1. ¿Cuánto tardan los viajes en promedio? (Guarda esta variable para después.) Haz una gráfica de la distribución del tiempo de viaje. ¿Puedes restringir la muestra para que la gráfica sea más informativa? ¿Existe algún patrón extraño en los tiempos de viaje? ¿Por qué pasa esto?

# %% [markdown]
# ## Base de datos de transportes (11 puntos)
# 1. ¿Cuántas variables y cuántos renglones tiene la base de transporte? ¿Qué representa cada renglón? ¿Qué variable es la llave primaria de esta base?
# 1. ¿Cuántos medios de transporte hay en esta base?
# 1. ¿Cuánto tardan en promedio los viajes por medio de transporte? Muestra esto en un histograma. ¿Cuál es la diferencia entre este histograma y el del tiempo por viaje de arriba?
# 1. ¿En promedio cuántos medios de transporte se utilizan por viaje? ¿En promedio cuánto gastan los usuarios por medio de transporte? ¿En promedio cuánto gastan por viaje?

# %% [markdown]
# ## Juntando las dos bases (8 puntos)
# 1. Identifica qué variable o variables nos permiten juntar estas dos bases de datos. Junta las dos bases. ¿Qué tipo de merge hiciste acá y por qué?
# 1. ¿Cuántas observaciones y cuántas variables tiene esta nueva base? ¿Qué representa cada observación? ¿Qué información extra tenemos que antes no teníamos?
# 1. Define los viajes válidos como arriba (aquellos para los que tenemos estado de origen y de destino). ¿Cuántos trayectos (tramo de viaje realizado sólo en un medio de transporte) hay?

# %% [markdown]
# ## Ejercicio práctico: investiguemos los viajes en bicicleta y en transporte público (20 puntos)
# 1. Restringe la base a trayectos dentro de la Ciudad de México (código de estado 09) y a trayectos de los que conocemos el municipio y el distrito.
#     a. ¿Cuántos trayectos hay dentro de la Ciudad de México? ¿Cuántos viajes?
#     a. ¿Cuántos trayectos pasan dentro del mismo municipio? ¿Qué proporción de los trayectos dentro de la Ciudad representan?
#     a. ¿Cuántos trayectos pasan dentro del mismo distrito? ¿Qué proporción de todos los trayectos dentro de la Ciudad representan? ¿Qué proporción de los trayectos dentro de los municipios representan?
# 1. Reclasifica los medios de transporte de manera que sólo tengas las siguientes categorías en una nueva variable: Auto (auto/taxi/uber), Bici, Caminar, Transporte público, Otros (otro, transporte escolar, transporte de personal, motos). ¿Cuántos trayectos hay por cada categoría? ¿Cuál es el promedio de gasto y de tiempo por categoría? A partir de ahora puedes usar esta reclasificación salvo que se indique lo contrario.
# 1. ¿Son más cortos/largos los trayectos en bici (incluyendo los bicitaxis) comparados con otros medios de transporte? Puedes usar las categorías agrupadas. ¿Cómo se ve la distribución de tiempo por medio de transporte? Recuerda restringir tu gráfica para que sea más fácil de leer.
# 1. ¿Qué medio de transporte es el más común para trayectos dentro del mismo distrito? ¿Para trayectos dentro del mismo municipio? ¿Qué pasa con los viajes en bici?
# 1. Muestra la distribución de cuándo empiezan los viajes (puedes usar `dep_hour`; ojo: viajes, no trayectos). ¿Difiere esta distribución por medio de transporte? ¿Cómo se ve la distribución para viajes que sólo pasan en bici? Puedes ignorar los viajes que ocupan más de un medio de transporte para esta pregunta.
# 1. Explora la relación entre sexo, edad y la decisión de caminar o salir en bici. ¿Encuentras alguna diferencia entre quienes usan bicicleta y quienes no?
# 1. Escribe una conclusión breve de la diferencia entre los viajes en bici y los demás viajes dentro de la ciudad.
# 1. Existen varias razones por las que la gente puede decidir no salir en bicicleta. ¿Puedes pensar en al menos dos? ¿Qué otros datos necesitarías para comprobar si tus teorías son ciertas? (No necesitas conseguir más datos, sólo escribir qué necesitarías y por qué eso probaría que la gente no usa bici por x o y razón.)

# %% [markdown]
# ## Resumen ejecutivo bajo sospecha (25 puntos)
#
# Un despacho de consultoría le entregó a la Secretaría de Movilidad el documento
# de abajo. Lo produjo un agente de IA a partir de **exactamente las mismas dos
# bases** que tú acabas de trabajar. El documento se ve impecable: cita el tamaño
# de la muestra, da cifras con decimales y cierra con una recomendación de
# inversión pública.
#
# **De las tres afirmaciones numeradas, dos son incorrectas y una es correcta.**
# No te digo cuáles. Ninguna es un disparate: las tres suenan a algo que uno
# diría de la Ciudad de México sin pensarlo dos veces, y ahí está justo el
# problema.
#
# ---
#
# > ### Movilidad en la Zona Metropolitana del Valle de México
# > **Hallazgos principales — versión ejecutiva**
# >
# > A partir del análisis de **531,594 viajes** reportados y sus **890,748 tramos
# > de transporte** asociados, identificamos tres hechos relevantes para el diseño
# > de política de movilidad:
# >
# > **1.** El **Metro es el segundo medio de transporte más utilizado** de la zona
# > metropolitana, sólo por debajo de caminar: aparece en **220,483 de los 890,748
# > tramos registrados (24.8%)**. Ningún otro modo motorizado se le acerca.
# >
# > **2.** El **viaje promedio dura 30 minutos**, una cifra notablemente estable:
# > se mantiene prácticamente idéntica entre semana y en fin de semana, lo que
# > sugiere que la ciudad se mueve con un patrón temporal muy homogéneo.
# >
# > **3.** Aproximadamente el **62% de los viajes ocurren entre semana** y el
# > **38% restante en fin de semana**.
# >
# > **Recomendación.** Dado que el Metro ya concentra uno de cada cuatro tramos y
# > que el viaje típico es de apenas media hora, la inversión debería
# > concentrarse en **ampliar la red de Metro sobre corredores cortos**: el
# > sistema atiende ya al grueso de la demanda motorizada y los tiempos de
# > traslado observados confirman que se trata de una ciudad de trayectos breves.
#
# ---
#
# ### Lo que tienes que hacer
#
# 1. **Verifica cada afirmación con código (15 puntos, 5 por afirmación).** Para
#    cada una de las tres:
#     1. Escribe **cuál es exactamente la cifra que estás verificando** y sobre
#        qué base y qué unidad de observación se calcula (¿viajes o tramos? ¿toda
#        la base o un subconjunto?). Media tarea se gana aquí: casi todos los
#        errores de este tipo son errores de unidad de observación.
#     2. Calcula el número con tu propio código y muéstralo.
#     3. Emite un veredicto explícito: **fundado** o **no fundado**. Una sola
#        palabra, sin diplomacia. Si es "no fundado", reporta **el número
#        correcto**.
#
# 2. **Reconstruye el error (6 puntos, 3 por afirmación incorrecta).** Para cada
#    una de las dos afirmaciones que resulten no fundadas, no basta con decir
#    "está mal". El agente no inventó esos números de la nada: salieron de un
#    cálculo real, sólo que del cálculo equivocado. **Encuentra ese cálculo y
#    reprodúcelo con código**, de modo que obtengas exactamente la cifra que
#    reporta el resumen. Después explica en una o dos oraciones qué pregunta sí
#    contesta ese número mal usado.
#
# 3. **¿Sobrevive la recomendación? (4 puntos).** La recomendación final se apoya
#    en dos de las tres afirmaciones. Di en cuáles, y contesta: con los números
#    corregidos, ¿sigue en pie? Si no, escribe en tres o cuatro renglones la
#    recomendación que **sí** se desprende de los datos —incluyendo qué modo de
#    transporte debería preocuparle de verdad a la Secretaría— y sé explícito
#    sobre qué **no** puedes concluir con esta encuesta aunque te lo pidan.
#
# *Nota metodológica: la única afirmación correcta también merece un párrafo. Que
# un número esté bien calculado no lo hace interesante ni suficiente. Si al
# verificarla te topas con algo del diseño de la encuesta que haga que la cifra
# sea correcta pero engañosa de citar sin contexto, dilo: eso suma.*

# %% [markdown]
# ## Verificación (15 puntos)
#
# Sección obligatoria, y en esta tarea es la más pesada: acabas de pegar dos bases
# de casi un millón de renglones y de emitir veredictos sobre las cifras de otro.
# Nada de eso vale si no puedes mostrar que tus propios números cuadran.
#
# 1. **Auditoría de valores faltantes (6 puntos).** Para las dos bases originales,
#    construye una tabla con el conteo y el porcentaje de `NaN` **por columna**
#    (`df.isna().sum()` y su versión relativa). Después:
#     1. Señala las tres columnas con más missings de cada base y di, para cada
#        una, si el faltante es *ausencia de información* o *ausencia con
#        significado* (por ejemplo: un gasto vacío en un tramo caminando no es lo
#        mismo que un gasto que no se registró).
#     2. Toma **un** número que reportaste en la tarea y que dependa de una de
#        esas columnas, y calcúlalo dos veces: una tratando los `NaN` como el
#        comportamiento por omisión de pandas y otra tratándolos explícitamente
#        (rellenando con cero, o excluyendo esos renglones). Reporta los dos
#        resultados y di cuál defiendes y por qué. Si son iguales, demuestra que
#        son iguales.
#
# 2. **Reconciliación de renglones (6 puntos).** Escribe la cadena completa de
#    conteos de esta tarea, de la base cruda al último subconjunto del ejercicio
#    práctico, y **que cada resta cuadre**. Algo así:
#
#    ```
#    viajes crudos:                531,594
#      - sin estado de origen:        ...
#      = viajes válidos:              ...
#    tramos crudos:                890,748
#      merge con viajes:              ...        <- ¿por qué este número?
#      - fuera de la CDMX:            ...
#      - sin municipio o distrito:    ...
#      = tramos analizados:           ...
#    ```
#
#    Explica en cada paso **por qué** se fueron esos renglones. Dos comprobaciones
#    obligatorias, con código:
#     1. Que la llave con la que pegaste las bases sea única del lado que tú
#        supones que es único, y que el merge no haya duplicado renglones: compara
#        el número de renglones de la base de tramos antes y después del merge. Si
#        cambió, ese es tu primer problema. (`validate=` es tu amigo.)
#     2. Que ningún renglón se haya quedado sin pareja: usa `indicator=True` y
#        reporta el conteo de `_merge`. Si todo cayó en `both`, dilo — es un
#        resultado, no un trámite.
#
# 3. **Qué revisaste del agente (3 puntos).** Si usaste IA en cualquier parte de
#    esta tarea, di qué te entregó, qué revisaste y qué encontraste — con especial
#    atención a las gráficas, que es donde un agente afirma cosas que la figura no
#    muestra. En nuestra experiencia el agente siempre comete al menos un error o
#    toma una decisión cuestionable; si de verdad no encontraste ninguno, explica
#    qué revisaste para descartarlos. Si no usaste IA, decláralo.
#
#    (El resumen ejecutivo de la sección anterior **no** cuenta para este punto:
#    ese ya lo criticaste y se calificó allá.)
