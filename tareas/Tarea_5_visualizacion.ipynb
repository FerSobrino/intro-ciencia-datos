# %% [markdown]
# # <center>Tarea 5 — Visualización</center>
#
# **Instrucciones:**
#
# 1. Nombra tu archivo `tarea_5.ipynb` (5 puntos).
# 2. Escribe tu nombre completo y, después, esta declaración:
#    *Este trabajo es mío y sigue la integridad académica del Tec de
#    Monterrey. La transcripción de IA que entrego corresponde
#    íntegramente a este trabajo.*
# 3. Anota los nombres de los compañeros con quienes discutiste la
#    tarea.
# 4. Uso de IA: permitido. Adjunta la transcripción completa de tus
#    conversaciones (archivo aparte o celda al final). Sin
#    transcripción, la tarea no se califica. Si no usaste IA,
#    decláralo.
# 5. Incluye la sección final de **Verificación**.
# 6. Descarga tu `.ipynb` y súbelo a Canvas junto con la transcripción.
#
# ---
#
# **Puntos por sección**
#
# | Sección | Puntos |
# |---|---|
# | Problemas de visualización | 20 |
# | Identificación de patrones | 15 |
# | Creación de reporte para presentación | 30 |
# | La gráfica del agente | 20 |
# | Verificación | 10 |
# | Nombre del archivo, declaración y compañeros | 5 |
# | **Total** | **100** |
#
# ---
#
# Para esta tarea hay que construir visualizaciones. Recuerda que, aunque no hay un estándar
# estricto para juzgar si una visualización es legible o no, factores como la legibilidad, la
# elección de colores (no elección estética sino lógica; por ejemplo, no usar colores donde no son
# necesarios, o usar tres tonos de azul sumamente parecidos para algo que debería ser
# diferenciable), el etiquetado correcto de los datos e incluso el tamaño de la visualización
# afectan su calidad. Además, recuerda que hay ciertos tipos de gráficas que favorecen a ciertos
# tipos de datos (piensa en categóricos vs. numéricos vs. geográficos).
#
# Usa las herramientas que quieras. Lo que se califica es que la gráfica responda a la pregunta,
# que esté correctamente etiquetada y que puedas defender cada decisión de diseño.
#
# Cualquiera de tus tareas entregadas puede tocarte en una **defensa
# oral** (10 minutos, sin IA, con tu notebook abierto). Antes de entregar,
# pregúntate: *¿podría explicar y modificar cada celda de esto?* Si una
# celda no la entiendes, pídele al agente que te la explique — para eso sí
# es buenísimo.

# %%
## Escribe aquí tu nombre completo, la declaración requerida y con quién trabajaste.

# %% [markdown]
# ## Problemas de visualización (20 puntos)
#
# 1. Observa la siguiente gráfica y:
#
#     a. Identifica al menos 3 problemas que tiene esta visualización.
#
#     b. Para cada uno de los problemas que identificaste, ¿cuál es una mejor opción?
#
# <img src="../images/bananas.jpeg" alt="Gráfica original de producción de plátano" width="50%"/>
#
# 2. Importa el conjunto de datos *bananas.csv* que se encuentra en la carpeta *data*. El conjunto
#    de datos original se obtuvo descargándolo del siguiente enlace. ¡Ojo! Este enlace no es
#    utilizable directamente por `pd.read_csv()` (trata de pensar por qué):
#    https://www.hbs.edu/businesshistory/courses/teaching-resources/historical-data-visualization/details?data_id=1
#
#     a. Asigna la base de datos a un data frame que se llame `bananas`. Conviértela en _tidy_.
#
#     b. Haz una visualización que contenga a los mismos países y los 12 puntos más recientes en el
#        tiempo (ya que la gráfica original es anual y los datos proporcionados son quinquenales),
#        siguiendo tus propias recomendaciones de la respuesta 1b. Recuerda que tu gráfica debe
#        utilizar la visualización correcta para el tipo de datos, además de ser legible,
#        comprensible y propiamente etiquetada.

# %% [markdown]
# **Tus respuestas a 1a y 1b aquí** (edita esta celda de markdown)

# %%
# Tu código para el punto 2 aquí...

# %% [markdown]
# ## Identificación de patrones (15 puntos)
#
# El conjunto de datos llamado **Iris** es comúnmente utilizado para realizar pruebas de exploración
# visual de datos y de clusterización (posiblemente lo retomemos más adelante en el curso, durante
# el tema de aprendizaje no supervisado). Contiene mediciones del ancho y largo de los pétalos y
# sépalos de flores pertenecientes a tres especies de iris, y ha sido utilizado desde 1936. Viene
# precargado como parte de la librería `seaborn`.
#
# a. Importa el conjunto de datos **iris** directamente de la librería `seaborn` utilizando el
#    siguiente comando:
#
# `iris = sns.load_dataset('iris')`
#
# 1. Grafica en un _scatterplot_ todas las combinaciones de pares de covariables (son 6
#    combinaciones en total), usando un color diferente para cada especie de iris. Utiliza la
#    sintaxis de `fig, ax` para acomodar las 6 gráficas en una cuadrícula de 2 filas y 3 columnas.
#
# 2. ¿Qué puedes observar? ¿Hay especies que se parezcan en algo? ¿Las tres especies son
#    completamente diferenciables solamente por las mediciones de sus pétalos, o son necesarias
#    mediciones de otros atributos como las hojas, el tallo, la morfología de los pétalos, la altura
#    de la planta, etc.?

# %%
# Tu código aquí...

# %% [markdown]
# **Tu respuesta a la pregunta 2 aquí** (edita esta celda de markdown)

# %% [markdown]
# ## Creación de reporte para presentación (30 puntos)
#
# Imagina que el dueño de un restaurante te pide que le entregues visualizaciones interesantes de
# los datos de su restaurante, y está especialmente interesado en _insights_ que tengan que ver con
# las propinas (tips).
#
# a. Importa el conjunto de datos **tips** directamente de la librería `seaborn` utilizando el
#    siguiente comando:
#
# `tips = sns.load_dataset('tips')`
#
# b. Realiza visualizaciones para las siguientes preguntas. Considera el tipo de dato(s) que estás
#    mostrando para elegir el tipo de gráfica correcto:
#
# 1. ¿Cuál es la distribución de `total_bill`? ¿Es simétrica?
# 2. ¿Cuál es la distribución de `tip`? ¿Es simétrica?
# 3. ¿Cuál es la distribución de la proporción de propina que deja cada grupo? Considera que
#    `total_bill` no incluye `tip`. ¿Es simétrica?
# 4. ¿Hay alguna tendencia en los días de la semana en los que la gente deje más propina?
#    (Considera con cuidado cuál variable es relevante graficar aquí; argumenta tu elección.)
# 5. ¿Cuánto deja en promedio de propina la gente en cada comida del día (`time`)? (Considera con
#    cuidado cuál variable es relevante graficar aquí; argumenta tu elección.)
# 6. ¿Hay alguna relación entre el tamaño del grupo (`size`) y la propina? (Considera con cuidado
#    cuál variable es relevante graficar aquí; argumenta tu elección.)
# 7. Toma en cuenta las variables `sex` y `smoker` para caracterizar grupos de personas. ¿Cuál grupo
#    deja menos y cuál más propina, en general? (Considera con cuidado cuál variable es relevante
#    graficar aquí; argumenta tu elección.)

# %%
# Tu código aquí...

# %% [markdown]
# **Tus interpretaciones aquí** (edita esta celda de markdown)

# %% [markdown]
# ## La gráfica del agente (20 puntos)
#
# El dueño del restaurante regresa con una pregunta concreta:
#
# > **¿Los grupos grandes dejan proporcionalmente menos propina que los grupos pequeños?**
#
# Vas a responderla con **una sola figura**, generada por una IA. Pero el orden importa: primero
# especificas, después generas. Un agente hace exactamente lo que le pides; si tu petición es
# "hazme una gráfica bonita de propinas", vas a recibir una gráfica bonita que no responde nada.
#
# Los cuatro incisos son secuenciales y se califican por separado. **No brinques el inciso a.**

# %% [markdown]
# ### a. Especificación previa (7 puntos) — antes de abrir el chat
#
# En la celda de abajo, y **antes de pedirle nada a una IA**, escribe la especificación de la
# figura. Debe ser lo bastante precisa como para que dos personas distintas produzcan
# esencialmente la misma gráfica a partir de ella. Como mínimo:
#
# - **Variable de interés.** "La propina" no basta: ¿`tip`, o `tip / total_bill`? Escribe la
#   fórmula exacta y di por qué esa es la que responde *esta* pregunta.
# - **Unidad de observación.** ¿Un punto por mesa, o un resumen por tamaño de grupo?
# - **Agregación.** Si resumes, ¿media, mediana o la distribución completa? ¿Por qué esa y no otra?
#   (Piensa qué le hace a la media una mesa que dejó 70% de propina, y cuántas mesas hay con
#   `size = 6`.)
# - **Tipo de gráfica** y por qué es el correcto para esos tipos de dato.
# - **Ejes**: qué variable va en cada uno, con unidades y rango.
# - **Cómo se ve la respuesta.** Describe, con palabras, qué patrón visual significaría "sí, los
#   grupos grandes dejan proporcionalmente menos" y cuál significaría "no". Si no puedes escribir
#   esto *antes* de ver la gráfica, la gráfica no puede refutarte nada.
# - **Qué NO debe tener**: al menos dos cosas que quieres evitar explícitamente (por ejemplo, color
#   usado para codificar algo que ya está en el eje x, o una línea de tendencia sobre una variable
#   discreta).
#
# Esta especificación **se congela**. Si más adelante te das cuenta de que estaba mal, no la
# borres: agrega abajo "Corrección:" y explica qué cambiaste y por qué.

# %% [markdown]
# **Tu especificación aquí** (edita esta celda de markdown, antes de usar la IA)
#
# - Variable de interés:
# - Unidad de observación:
# - Agregación:
# - Tipo de gráfica:
# - Eje x / eje y:
# - Cómo se vería un "sí" / cómo se vería un "no":
# - Qué NO debe tener:

# %% [markdown]
# ### b. El prompt (3 puntos)
#
# Pídele la figura a la IA de tu elección (ChatGPT, Claude, Gemini, Copilot, etc.). Pega aquí
# **el prompt exacto** que usaste, tal cual, y di qué herramienta usaste. La conversación completa
# va en la transcripción que entregas aparte; aquí solo el prompt.

# %% [markdown]
# **Herramienta usada:**
#
# **Prompt (copiado tal cual):**
#
# ```
# ...
# ```

# %% [markdown]
# ### c. El resultado (4 puntos)
#
# Pega el **código final** de la figura en la celda de código de abajo y ejecútalo, de manera que la
# gráfica aparezca en tu notebook. Debe correr sin errores en tu máquina y debe ser la versión que
# tú avalas, no necesariamente la primera que te dio el agente.

# %%
# Código final de la figura del agente (revisado por ti). Debe correr y producir la gráfica.

# %% [markdown]
# ### d. Bitácora de correcciones (6 puntos)
#
# La parte que de verdad se califica. Documenta la diferencia entre lo que pediste y lo que
# recibiste:
#
# 1. **¿Qué le faltó o qué se inventó el primer intento?** Sé concreto. Ejemplos del tipo de cosas
#    que suelen pasar: graficó `tip` en pesos en vez de la proporción; usó media donde la
#    distribución es asimétrica; puso `size` como variable continua con línea de regresión; no
#    etiquetó los ejes o los etiquetó con el nombre de la columna en inglés; ignoró que hay muy
#    pocas mesas de 5 y 6 personas y las mostró con el mismo peso visual que las de 2.
# 2. **¿Qué tuviste que pedirle explícitamente** para acercarlo a tu especificación? Cita las
#    instrucciones adicionales.
# 3. **Si el primer intento salió bien**, no inventes un error: explica qué revisaste
#    específicamente para concluir que estaba bien (ejes, agregación, tipo de gráfica, número de
#    observaciones por grupo) y por qué crees que tu especificación fue lo bastante buena.
# 4. **La respuesta.** En dos o tres renglones: según tu figura final, ¿los grupos grandes dejan
#    proporcionalmente menos propina? Incluye la limitación más importante de esta conclusión
#    (¿cuántas mesas grandes hay realmente en estos datos?).

# %% [markdown]
# **Tu bitácora aquí** (edita esta celda de markdown)
#
# **1. Qué salió mal en el primer intento:**
#
# **2. Qué le pedí explícitamente para corregirlo:**
#
# **3. Qué revisé:**
#
# **4. La respuesta a la pregunta del dueño:**

# %% [markdown]
# ## Verificación (10 puntos)
#
# Toda tarea del curso cierra aquí. No se trata de repetir lo que hiciste, sino de mostrar **cómo
# comprobaste que está bien**. Ejecuta los tres chequeos y escribe la conclusión de cada uno.
#
# 1. **Un número de tu propia gráfica, por cálculo directo (4 pts).** Elige un número que se pueda
#    leer en tu figura final de la sección *La gráfica del agente* (la altura de una barra, la
#    posición de una mediana, el valor de un punto agregado). Calcúlalo otra vez a mano con pandas,
#    en la celda de abajo, sin reutilizar el código de la figura. Reporta los dos valores y si
#    coinciden. Si no coinciden, encuentra por qué antes de entregar: casi siempre significa que la
#    gráfica está agregando algo distinto de lo que crees.
#
# 2. **Conteo de renglones del *tidy* (3 pts).** Para `bananas`: ¿cuántos renglones y columnas tenía
#    antes de hacerla tidy y cuántos después? ¿El número después es el que esperabas
#    (países × periodos)? ¿Cuántos valores faltantes hay y qué hiciste con ellos — los quitaste, los
#    dejaste, o los graficaste como cero? (Graficar un faltante como cero es un error clásico y
#    cambia la conclusión.)
#
# 3. **Etiquetas contra datos (3 pts).** Toma dos de las figuras que entregaste y verifica, columna
#    por columna, que lo que dice cada etiqueta de eje es efectivamente lo que se está graficando en
#    ese eje, y que las unidades son correctas (dólares vs. proporción vs. porcentaje). Confundir
#    `tip` con `tip/total_bill` en una etiqueta es motivo suficiente para que el dueño del
#    restaurante tome una mala decisión.
#
# Cierra con una línea sobre el uso de IA: qué error o decisión cuestionable encontraste en el
# trabajo del agente; si no encontraste ninguno, qué revisaste para descartarlos. Si no usaste IA en
# esta tarea, decláralo.

# %%
# Chequeo 1: recalcula a mano un número que aparece en tu figura final.
# Chequeo 2: conteos antes/después del tidy y valores faltantes.

# %% [markdown]
# **Conclusiones de tu verificación aquí** (edita esta celda de markdown)
#
# 1. Número recalculado — valor en la gráfica: ___ / valor calculado: ___ / ¿coinciden?
# 2. `bananas`: ___ renglones × ___ columnas antes; ___ × ___ después. Faltantes: ___ . Qué hice con ellos:
# 3. Etiquetas revisadas:
# 4. Uso de IA — errores encontrados o qué revisé para descartarlos:
