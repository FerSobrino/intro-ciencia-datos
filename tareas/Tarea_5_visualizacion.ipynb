# %% [markdown]
# # <center>Tarea 5</center>
#
# Instrucciones:
# 1. Ponle de nombre a tu tarea `tarea_5.ipynb` un Jupyter Notebook (5 puntos)
# 2. Escribe tu nombre comleto y tus iniciales en tu notebook después de la siguiente nota:
# *Este trabajo es mio y sigue la integridad académica del Tec. de Monterrey*
# 3. Agrega los nombres de todos los compañeros con los que trabajaste. Recuerda que puedes discutir con tus compañeros pero cada quien tiene que entregar su tarea.
# 4. **ADVERTENCIA!** solo puedes utilizar las librerias que explicitamente se mencionen. El uso de cualquier otra libreria para resolver algún ejercicio será tomado como plagio :(
# 5. Librerias: `pandas`, `numpy`, `statsmodels`, `matplotlib`, `seaborn`
# 6. Descarga tu .ipynb y subelo a canvas!
#
# Para esta tarea, hay que construir visualizaciones. Recuerda que, aunque no hay un estándar estricto para juzgar si una visualización es legible o no, factores como legibilidad, elección de colores (no elección estética sino lógica, e.g. no usar colores donde no es necesario, usar tres tonos de azul sumamente parecidos para algo que debería ser diferenciable, etc.), etiquetado correcto de los datos e incluso tamaño de la visualización, afectan la calidad. Además, recuerda que hay ciertos tipos de gráficas que favorecen a ciertos tipos de datos (piensa en categóricos vs. numéricos vs geográficos).
#
#
# ### Problemas de visualización (25 puntos)
#
# 1. Observa la siguiente gráfica y:
#
#     a. Identifica al menos 3 problemas que tiene esta visualización.
#
#     b. Para cada uno de los problemas que identificaste, ¿cuál es una mejor opción?
#
# <img src="../images/bananas.jpeg" alt="alternative text" width="50%"/>
#
# 2. Importa el conjunto de datos *bananas.csv* que se encuentra en la carpeta *data*. El conjunto de datos original se obtuvo de descargarlo del siguiente enlace. ¡Ojo! este enlance no es utilizable directamente por `pd.read_csv()` (trata de pensar por qué): https://www.hbs.edu/businesshistory/courses/teaching-resources/historical-data-visualization/details?data_id=1
#
#     a. Asigna la base de datos a un data frame que se llame `bananas`. Conviértela en _tidy_.
#
#     b. Haz una visualización que contenga a los mismos países y los 12 puntos más recientes en el tiempo (ya que la gráfica original es anual y los datos proporcionados son quinquenales), siguiendo tus propias recomendaciones de la respuesta 1b. Recuerda que tu gráfica debe utilizar la visualización correcta para el tipo de datos, además de ser legible, comprensible y propiamente etiquetada.
#
# ### Identificación de patrones (30 puntos)
#
# El conjunto de datos llamados **Iris** es comúnmente utilizado para realizar pruebas de exploración visual de datos y de clusterización (posiblemente los retomemos más adelante en el curso, durante el tema de aprendizaje no supervisado). Estos contienen mediciones del ancho y largo de los pétalos y sépalos de flores pertenencientes a tres especies de flores iris y han sido utilizados desde 1936. Viene precargado como parte de la librería
#
# a. Importa el conjunto de datos **iris** directamente de la librería `seaborn` utilizando el siguiente comando:
#
# `iris = sns.load_dataset('iris')`
#
# 1. Grafica en un _scatterplot_ todas las combinaciones de pares de covariables (son 6 combinaciones en total), usando un color diferente para cada especie de iris. Utiliza la sintaxis de `fig, ax` para agregar las 6 gráficas en una cuadrícula de 2 filas y 3 columnas.
#
# 2. ¿Qué puedes observar? ¿Hay especies que se parezcan en algo? ¿Las tres especies son completamente diferenciables solamente por las mediciones de sus pétalos, o son necesarias mediciones de otros atributos como las hojas, el tallo, la morfología de los pétalos, la altura de la planta, etc.?
#
# ### Creación de reporte para presentación (40 puntos)
#
# Imagina que el dueño de un restaurante te pide que le entregues visualizaciones interesantes de los datos de su restaurante, y está especialmente interesado en _insights_ que tengan que ver con las propinas (tips).
#
# a. Importa el conjunto de datos **tips** directamente de la librería `seaborn` utilizando el siguiente comando:
#
# `tips = sns.load_dataset('tips')`
#
# b. Realiza visualizaciones para las siguientes preguntas. Considera el tipo de dato(s) que estás mostrando, para elegir el tipo de gráfica correcto:
#
# 1. ¿Cuál es la distribución de `total_bill`? ¿Es simétrica?
# 2. ¿Cuál es la distribución de `tip`? ¿Es simétrica?
# 3. ¿Cuál es la distribución de la proporción de propina que deja cada grupo? Considera que `total_bill` no incluye `tip`. ¿Es simétrica?
# 4. ¿Hay alguna tendencia en los días de la semana, en los que la gente deje más propina? (Considera con cuidado cuál variable es relevante graficar aquí, argumenta tu elección)
# 5. ¿Cuánto deja en promedio de propina la gente en cada comida del día (`time`)? (Considera con cuidado cuál variable es relevante graficar aquí, argumenta tu elección)
# 6. ¿Hay alguna relación entre el tamaño del grupo (`size`) y la propina? (Considera con cuidado cuál variable es relevante graficar aquí, argumenta tu elección)
# 7. Toma en cuenta las variables `sex` y `smoker` para caracterizar grupos de personas. Cuál grupo deja menos y cuál más propina, en general? (Considera con cuidado cuál variable es relevante graficar aquí, argumenta tu elección)
